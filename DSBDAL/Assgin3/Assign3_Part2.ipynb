# %%
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["species"] = iris.target_names[iris.target] #iris.target contains numbers: #0 → setosa #1 → versicolor #2 → virginica
#converts numbers into actual species names  
#species a categorical variable

# %%
df = df.rename(columns={
    "sepal length (cm)": "sepal_length",
    "sepal width (cm)": "sepal_width",
    "petal length (cm)": "petal_length",
    "petal width (cm)": "petal_width"
})# rename the name

# %%
df["species"].value_counts() #Counts how many flowers belong to each species
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.head() #show first 5 rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail() #last 5 records
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
#Calculate Statistics for Each Species
df[df["species"] == "setosa"]["sepal_length"].describe() #only Setosa flowers
# Out:
# count    50.00000
# mean      5.00600
# std       0.35249
# min       4.30000
# 25%       4.80000
# 50%       5.00000
# 75%       5.20000
# max       5.80000
# Name: sepal_length, dtype: float64

# %%
df[df["species"] == "versicolor"]["sepal_length"].describe()
# Out:
# count    50.000000
# mean      5.936000
# std       0.516171
# min       4.900000
# 25%       5.600000
# 50%       5.900000
# 75%       6.300000
# max       7.000000
# Name: sepal_length, dtype: float64

# %%
df[df["species"] == "virginica"]["sepal_length"].describe()
# Out:
# count    50.00000
# mean      6.58800
# std       0.63588
# min       4.90000
# 25%       6.22500
# 50%       6.50000
# 75%       6.90000
# max       7.90000
# Name: sepal_length, dtype: float64

# %%
df[df["species"] == "setosa"].describe() #species column from dataset
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %%
df[df["species"] == "versicolor"].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
df[df["species"] == "virginica"].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000
